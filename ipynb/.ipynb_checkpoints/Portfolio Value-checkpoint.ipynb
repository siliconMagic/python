# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize
from matplotlib.pyplot import plot, scatter, show
from pandas.io.data import DataReader
from datetime import datetime

# %%
# %matplotlib inline

# %%
start = datetime(2013,1,2)
end = datetime(2013,12,31)

# stock list
ticker = ['AAPL', 'AMZN', 'ATVI', 'BBBY', 'BRK.B', 'COST', 'DDD', 'DIS', 'DISCK', 'F', 'GLD', 'SBUX', 'SPY']
share = [635, 850, 12313, 1104, 840, 2115, 922, 2007, 1840, 5000, 1124, 2542, 165]

#set up DataFrames
daily_stock_price  = pd.DataFrame(index=pd.bdate_range(start, end)) # business days
daily_stock_share = pd.DataFrame(index=pd.bdate_range(start, end), columns=ticker)
daily_stock_value = pd.DataFrame(index=pd.bdate_range(start, end), columns=ticker)
daily_portfolio_value = pd.DataFrame(index=pd.bdate_range(start, end))

# %%
daily_stock_price = DataReader(ticker, 'google', start, end)['Close']

# %%
for i, s in enumerate(ticker):
    daily_stock_share[s] = share[i]
daily_stock_value = daily_stock_price * daily_stock_share
daily_portfolio_value = daily_stock_value.sum(axis=1)

# %%
daily_stock_price.head()
# Out:
#               AAPL    AMZN   ATVI   BBBY  BRK.B    COST    DDD    DIS  DISCK  \
# ﻿Date
# 2013-01-02  549.03  257.31  10.94  56.15  93.20  101.45  37.19  51.10  60.16
# 2013-01-03  542.10  258.48  11.01  56.62  93.62  102.49  37.98  51.21  60.33
# 2013-01-04  527.00  259.15  11.17  56.90  93.85  102.16  39.23  52.19  60.74
# 2013-01-07  523.90  268.46  11.18  56.42  93.45  101.37  40.45  50.97  60.21
# 2013-01-08  525.31  266.38  10.99  56.38  93.81  101.18  39.10  50.76  61.97
#
#                 F     GLD   SBUX     SPY
# ﻿Date
# 2013-01-02  13.20  163.17  55.00  146.06
# 2013-01-03  13.46  161.20  55.37  145.73
# 2013-01-04  13.57  160.44  55.69  146.37
# 2013-01-07  13.43  159.43  55.72  145.97
# 2013-01-08  13.35  160.56  55.62  145.55

# %%
daily_stock_price.tail()
# Out:
#               AAPL    AMZN   ATVI   BBBY   BRK.B    COST    DDD    DIS  DISCK  \
# ﻿Date
# 2013-12-24  567.67  399.20  18.17  78.65  117.43  118.69  86.07  73.85  81.85
# 2013-12-26  563.90  404.39  18.08  79.53  117.99  118.63  92.06  74.62  82.29
# 2013-12-27  560.09  398.08  17.82  79.32  118.00  118.53  90.79  74.35  82.33
# 2013-12-30  554.52  393.37  17.80  80.13  118.04  118.77  91.95  76.23  83.58
# 2013-12-31  561.02  398.79  17.83  80.30  118.56  119.02  92.93  76.40  83.86
#
#                 F     GLD   SBUX     SPY
# ﻿Date
# 2013-12-24  15.19  116.10  78.57  182.93
# 2013-12-26  15.33  116.74  78.88  183.86
# 2013-12-27  15.30  117.12  78.57  183.84
# 2013-12-30  15.28  115.39  78.55  183.82
# 2013-12-31  15.43  116.12  78.39  184.69

# %%
daily_stock_share.head()
# Out:
#             AAPL  AMZN   ATVI  BBBY  BRK.B  COST  DDD   DIS  DISCK     F  \
# 2013-01-02   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-01-03   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-01-04   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-01-07   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-01-08   635   850  12313  1104    840  2115  922  2007   1840  5000
#
#              GLD  SBUX  SPY
# 2013-01-02  1124  2542  165
# 2013-01-03  1124  2542  165
# 2013-01-04  1124  2542  165
# 2013-01-07  1124  2542  165
# 2013-01-08  1124  2542  165

# %%
daily_stock_value.dropna().plot()

# %%
daily_portfolio_value = daily_portfolio_value.dropna()

# %%
daily_portfolio_value.plot()

# %%
year_return = daily_portfolio_value[-1:] - daily_portfolio_value[0]

# %%
percent_return = year_return / daily_portfolio_value[0]

# %%
print("Start: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value[0], daily_portfolio_value.index[0]))
print("  End: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value[-1], daily_portfolio_value.index[-1]))
print("  Min: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value.min(), daily_portfolio_value.idxmin()))
print("  Max: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value.max(), daily_portfolio_value.idxmax()))
print("Total return for the year is ${:,.2f} for a return of {:.2%}".format(year_return[0], percent_return[0]))
# Out:
# Start: $1,717,750.38 on 2013-01-02
#   End: $2,185,457.66 on 2013-12-31
#   Min: $1,682,770.40 on 2013-02-04
#   Max: $2,187,013.09 on 2013-12-26
# Total return for the year is $467,707.28 for a return of 27.23%
