# %%
import pandas as pd
# from matplotlib.pyplot import show
from pandas.io.data import DataReader
from datetime import datetime, timedelta

# %%
# %matplotlib inline

# %%
end = datetime.today()
start = end - timedelta(days=365)

# stock list
ticker = ['AAPL', 'AMZN', 'ATVI', 'BBBY', 'BRK.B', 'COST', 'DDD', 'DIS', 'DISCK', 'F', 'GLD', 'SBUX', 'SPY']
share = [635, 850, 12313, 1104, 840, 2115, 922, 2007, 1840, 5000, 1124, 2542, 165]

#set up DataFrames
daily_stock_price  = pd.DataFrame(index=pd.bdate_range(start, end)) # business days
daily_stock_share = pd.DataFrame(index=pd.bdate_range(start, end), columns=ticker)
daily_stock_value = pd.DataFrame(index=pd.bdate_range(start, end), columns=ticker)
daily_portfolio_value = pd.DataFrame(index=pd.bdate_range(start, end))

# %%
daily_stock_price = DataReader(ticker, 'yahoo', start, end)['Adj Close']

# %%
for i, s in enumerate(ticker):
    daily_stock_share[s] = share[i]
daily_stock_value = daily_stock_price * daily_stock_share
daily_portfolio_value = daily_stock_value.sum(axis=1)

# %%
daily_stock_price.head()
# Out:
#               AAPL    AMZN   ATVI   BBBY  BRK.B    COST    DDD    DIS  DISCK  \
# Date
# 2013-01-28  441.37  276.04  11.25  58.51  97.12  101.41  39.67  53.70  63.01
# 2013-01-29  449.65  260.35  11.27  58.08  97.24  102.27  41.33  53.33  63.11
# 2013-01-30  448.24  272.76  11.16  58.54  96.88  101.45  40.27  53.13  63.29
# 2013-01-31  446.92  265.50  11.25  58.70  96.93  101.26  38.57  53.22  63.71
# 2013-02-01  445.09  265.00  11.50  59.22  98.00  103.05  39.03  53.92  64.19
#
#                 F     GLD   SBUX     SPY
# Date
# 2013-01-28  13.52  160.29  55.29  147.10
# 2013-01-29  12.89  160.99  54.87  147.68
# 2013-01-30  12.69  162.19  55.27  147.10
# 2013-01-31  12.71  161.20  55.39  146.74
# 2013-02-01  12.78  161.45  56.12  148.25
#
# [5 rows x 13 columns]

# %%
daily_stock_price.tail()
# Out:
#               AAPL    AMZN   ATVI   BBBY   BRK.B    COST    DDD    DIS  DISCK  \
# Date
# 2014-01-17  540.67  399.61  16.96  66.05  115.07  116.29  90.53  73.98  74.53
# 2014-01-21  549.07  407.05  16.79  66.05  115.15  114.93  85.63  74.20  74.13
# 2014-01-22  551.51  404.54  16.74  65.13  115.26  113.75  88.26  75.31  74.30
# 2014-01-23  556.18  399.87  16.67  65.67  113.50  112.80  85.30  74.79  73.98
# 2014-01-24  546.07  387.60  16.67  64.59  111.81  112.13  79.87  72.72  73.59
#
#                 F     GLD   SBUX     SPY
# Date
# 2014-01-17  16.52  120.93  74.90  183.64
# 2014-01-21  16.41  119.70  73.65  184.18
# 2014-01-22  16.55  119.19  73.60  184.30
# 2014-01-23  16.43  121.79  73.39  182.79
# 2014-01-24  15.83  122.29  74.98  178.89
#
# [5 rows x 13 columns]

# %%
daily_stock_share.head()
# Out:
#             AAPL  AMZN   ATVI  BBBY  BRK.B  COST  DDD   DIS  DISCK     F  \
# 2013-01-28   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-01-29   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-01-30   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-01-31   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-02-01   635   850  12313  1104    840  2115  922  2007   1840  5000
#
#              GLD  SBUX  SPY
# 2013-01-28  1124  2542  165
# 2013-01-29  1124  2542  165
# 2013-01-30  1124  2542  165
# 2013-01-31  1124  2542  165
# 2013-02-01  1124  2542  165
#
# [5 rows x 13 columns]

# %%
daily_stock_value.dropna().plot()

# %%
daily_portfolio_value = daily_portfolio_value.dropna()

# %%
daily_portfolio_value.plot()

# %%
year_return = daily_portfolio_value[-1:] - daily_portfolio_value[0]

# %%
percent_return = year_return / daily_portfolio_value[0]

# %%
print("Start: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value[0], daily_portfolio_value.index[0]))
print("  End: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value[-1], daily_portfolio_value.index[-1]))
print("  Min: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value.min(), daily_portfolio_value.idxmin()))
print("  Max: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value.max(), daily_portfolio_value.idxmax()))
print("Total return for the year is ${:,.2f} for a return of {:.2%}".format(year_return[0], percent_return[0]))
# Out:
# Start: $1,686,957.87 on 2013-01-28
#   End: $2,075,569.62 on 2014-01-24
#   Min: $1,668,487.37 on 2013-02-04
#   Max: $2,187,013.09 on 2013-12-26
# Total return for the year is $388,611.75 for a return of 23.04%
