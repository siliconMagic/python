# %%
import pandas as pd
# from matplotlib.pyplot import show
from pandas.io.data import DataReader
from datetime import datetime, timedelta

# %%
# %matplotlib inline

# %%
end = datetime.today()
start = end - timedelta(days=365)

# stock list
ticker = ['AAPL', 'AMZN', 'ATVI', 'BBBY', 'BRK-B', 'COST', 'DDD', 'DIS', 'DISCK', 'F', 'GLD', 'SBUX', 'SPY']
share = [635, 850, 12313, 1104, 840, 2115, 922, 2007, 1840, 5000, 1124, 2542, 165]

#set up DataFrames
daily_stock_price  = pd.DataFrame(index=pd.bdate_range(start, end)) # business days
daily_stock_share = pd.DataFrame(index=pd.bdate_range(start, end), columns=ticker)
daily_stock_value = pd.DataFrame(index=pd.bdate_range(start, end), columns=ticker)
daily_portfolio_value = pd.DataFrame(index=pd.bdate_range(start, end))

# %%
daily_stock_price = DataReader(ticker, 'yahoo', start, end)['Adj Close']

# %%
for i, s in enumerate(ticker):
    daily_stock_share[s] = share[i]
daily_stock_value = daily_stock_price * daily_stock_share
daily_portfolio_value = daily_stock_value.sum(axis=1)

# %%
daily_stock_price.head()
# Out:
#               AAPL    AMZN   ATVI   BBBY   BRK-B    COST    DDD    DIS  DISCK  \
# Date
# 2013-04-25  398.31  274.70  14.57  67.69  107.47  107.98  35.12  61.24  71.29
# 2013-04-26  406.91  254.81  14.68  67.09  107.10  108.12  34.57  61.12  70.78
# 2013-04-29  419.51  249.74  14.79  68.39  106.61  107.48  35.77  62.23  70.87
# 2013-04-30  431.86  253.81  14.82  68.80  106.32  107.28  38.24  62.07  70.89
# 2013-05-01  428.46  248.23  14.60  68.81  106.12  107.08  37.67  62.44  70.56
#
#                 F     GLD   SBUX     SPY
# Date
# 2013-04-25  13.11  141.63  59.71  155.39
# 2013-04-26  13.31  140.91  59.21  155.11
# 2013-04-29  13.30  142.30  59.79  156.15
# 2013-04-30  13.35  142.77  60.04  156.52
# 2013-05-01  13.12  141.11  59.35  155.15
#
# [5 rows x 13 columns]

# %%
daily_stock_price.tail()
# Out:
#               AAPL    AMZN   ATVI   BBBY   BRK-B    COST    DDD    DIS  DISCK  \
# Date
# 2014-04-17  524.94  324.91  19.69  63.70  127.18  113.50  48.17  79.99  72.75
# 2014-04-21  531.17  330.87  19.69  63.68  126.50  114.10  49.06  79.11  72.44
# 2014-04-22  531.70  329.32  19.90  63.27  127.15  113.56  52.10  79.45  72.59
# 2014-04-23  524.75  324.58  19.63  62.92  127.20  114.79  50.48  79.52  72.16
# 2014-04-24  567.77  337.15  19.57  62.83  126.95  115.03  51.44  79.59  71.98
#
#                 F     GLD   SBUX     SPY
# Date
# 2014-04-17  16.00  124.75  70.15  186.39
# 2014-04-21  15.98  124.24  70.48  187.04
# 2014-04-22  16.10  123.78  71.15  187.89
# 2014-04-23  16.23  123.76  70.39  187.45
# 2014-04-24  16.32  124.56  71.09  187.83
#
# [5 rows x 13 columns]

# %%
daily_stock_share.head()
# Out:
#             AAPL  AMZN   ATVI  BBBY  BRK-B  COST  DDD   DIS  DISCK     F  \
# 2013-04-25   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-04-26   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-04-29   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-04-30   635   850  12313  1104    840  2115  922  2007   1840  5000
# 2013-05-01   635   850  12313  1104    840  2115  922  2007   1840  5000
#
#              GLD  SBUX  SPY
# 2013-04-25  1124  2542  165
# 2013-04-26  1124  2542  165
# 2013-04-29  1124  2542  165
# 2013-04-30  1124  2542  165
# 2013-05-01  1124  2542  165
#
# [5 rows x 13 columns]

# %%
daily_stock_value.dropna().plot()
# Out:
# /Users/davekensinger/.virtualenvs/test1/lib/python3.4/site-packages/IPython/core/formatters.py:239: FormatterWarning: Exception in image/png formatter: Could not create write struct
#   FormatterWarning,

# %%
daily_portfolio_value = daily_portfolio_value.dropna()

# %%
daily_portfolio_value.plot()

# %%
year_return = daily_portfolio_value[-1:] - daily_portfolio_value[0]

# %%
percent_return = year_return / daily_portfolio_value[0]

# %%
print("Start: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value[0], daily_portfolio_value.index[0]))
print("  End: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value[-1], daily_portfolio_value.index[-1]))
print("  Min: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value.min(), daily_portfolio_value.idxmin()))
print("  Max: ${:,.2f} on {:%Y-%m-%d}".format(daily_portfolio_value.max(), daily_portfolio_value.idxmax()))
print("Total return for the year is ${:,.2f} for a return of {:.2%}".format(year_return[0], percent_return[0]))
# Out:
# Start: $1,747,831.73 on 2013-04-25
#   End: $2,080,283.81 on 2014-04-24
#   Min: $1,729,720.52 on 2013-06-24
#   Max: $2,180,613.23 on 2013-12-26
# Total return for the year is $332,452.08 for a return of 19.02%
